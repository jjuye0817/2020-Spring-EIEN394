# %% [markdown]
# <a href="https://colab.research.google.com/github/jjuye0817/2020-Spring-EIEN394/blob/master/Lecture_24Apr20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lecture - 24Apr20
# <br> blomqvist@korea.ac.kr (do not hesistate to contact me!)
# <br> initial: Jong-Min Kim, 24-Apr-2020
# <br> test

# %%
import torch
import numpy
import matplotlib.pylab as plt
import matplotlib.image as mpimg

# %% [markdown]
# Derivatives of $f(x) = x^{2}$ at x = 1.0

# %%
x = torch.tensor(1.0, requires_grad=True)
y = x**2
y.backward()
print('solution=', x.grad)
# Out:
# solution= tensor(2.)

# %%
x = torch.linspace(-10, 10, 100000, requires_grad = True)
Y = x ** 2
#y = torch.sum(x ** 2)
y = Y.sum()

# %%
# Take the derivative with respect to multiple value. Plot out the function and its derivative

y.backward()

print(y)
print(x.grad)

plt.plot(x.detach().numpy(), Y.detach().numpy(), label = 'function')
#plt.plot(x.detach().numpy(), Y.detach().numpy(), label = 'function')
plt.plot(x.detach().numpy(), x.grad.detach().numpy(), label = 'derivative')
plt.xlabel('x')
plt.legend()
plt.show()
# Out:
# tensor(3333400., grad_fn=<SumBackward0>)
# tensor([-20.0000, -19.9996, -19.9992,  ...,  19.9992,  19.9996,  20.0000])

# %% [markdown]
# ## File from Google Drive

# %%
from google.colab import drive
drive.mount('/content/gdrive')

# %%
from google.colab import drive

drive.mount('/content/gdrive')

# %%
img1 = mpimg.imread("/content/gdrive/My Drive/Google Colab Notebooks/2020-Spring-PyTorch/Images_L3/Image1.tif")

print('shape of image=', img1.shape, img1.dtype, type(img1))
# Out:
# shape of image= (571, 482) uint8 <class 'numpy.ndarray'>

# %%
plt.imshow(img1, cmap='gray')
plt.axis('off')
plt.colorbar()
plt.savefig('img1.jpg')
